# %%
# !pip install conllu
# Out:
# Collecting conllu
#   Downloading conllu-4.5.2-py2.py3-none-any.whl (16 kB)
# Installing collected packages: conllu
# Successfully installed conllu-4.5.2

# %%
import pandas as pd

# %%
train_file = '../data/en_ewt-up-train.conllu'
test_file = '../data/en_ewt-up-test.conllu'

# %%
with open(train_file, 'r', encoding='utf-8') as f:
    train_data = f.read()

# %%
data = []
for doc in train_data.split('\n\n'):
    doc = doc.split('\n')
    sentences = ''
    for line in doc:
        if line and line[0] != '#':
            sentences += line + '\n'
    data.append(sentences)

# %%
train_df = pd.DataFrame([x.split('\t') for sent in data for x in sent.split('\n') if x])

# %%
train_df.shape
# Out:
# (204609, 46)

# %%
train_df[train_df[45].isnull()]
# Out:
#         0         1         2      3      4   \
# 0        1        Al        Al  PROPN    NNP
# 1        2         -         -  PUNCT   HYPH
# 2        3     Zaman     Zaman  PROPN    NNP
# 3        4         :         :  PUNCT      :
# 4        5  American  american    ADJ     JJ
# ...     ..       ...       ...    ...    ...
# 204604  22        on        on    ADP     IN
# 204605  23        my        my   PRON   PRP$
# 204606  24       car       car   NOUN     NN
# 204607  25         )         )  PUNCT  -RRB-
# 204608  26         .         .  PUNCT      .
#
#                                                 5   6          7   \
# 0                                      Number=Sing   0       root
# 1                                                _   1      punct
# 2                                      Number=Sing   1       flat
# 3                                                _   1      punct
# 4                                       Degree=Pos   6       amod
# ...                                            ...  ..        ...
# 204604                                           _  24       case
# 204605  Number=Sing|Person=1|Poss=Yes|PronType=Prs  24  nmod:poss
# 204606                                 Number=Sing  21        obl
# 204607                                           _   4      punct
# 204608                                           _   4      punct
#
#                   8              9   ...    36    37    38    39    40    41  \
# 0             0:root  SpaceAfter=No  ...  None  None  None  None  None  None
# 1            1:punct  SpaceAfter=No  ...  None  None  None  None  None  None
# 2             1:flat              _  ...  None  None  None  None  None  None
# 3            1:punct              _  ...  None  None  None  None  None  None
# 4             6:amod              _  ...  None  None  None  None  None  None
# ...              ...            ...  ...   ...   ...   ...   ...   ...   ...
# 204604       24:case              _  ...  None  None  None  None  None  None
# 204605  24:nmod:poss              _  ...  None  None  None  None  None  None
# 204606     21:obl:on  SpaceAfter=No  ...  None  None  None  None  None  None
# 204607       4:punct  SpaceAfter=No  ...  None  None  None  None  None  None
# 204608       4:punct              _  ...  None  None  None  None  None  None
#
#           42    43    44    45
# 0       None  None  None  None
# 1       None  None  None  None
# 2       None  None  None  None
# 3       None  None  None  None
# 4       None  None  None  None
# ...      ...   ...   ...   ...
# 204604  None  None  None  None
# 204605  None  None  None  None
# 204606  None  None  None  None
# 204607  None  None  None  None
# 204608  None  None  None  None
#
# [204474 rows x 46 columns]

# %%
train_data[train_data[21] !+ None]
# Out:
#      0         1         2      3     4            5     6      7          8   \
# 0     1        Al        Al  PROPN   NNP  Number=Sing     0   root     0:root
# 1     2         -         -  PUNCT  HYPH            _     1  punct    1:punct
# 2     3     Zaman     Zaman  PROPN   NNP  Number=Sing     1   flat     1:flat
# 3     4         :         :  PUNCT     :            _     1  punct    1:punct
# 4     5  American  american    ADJ    JJ   Degree=Pos     6   amod     6:amod
# ..   ..       ...       ...    ...   ...          ...   ...    ...        ...
# 219  18        in        in    ADP    IN            _    19   case    19:case
# 220  19   Vietnam   Vietnam  PROPN   NNP  Number=Sing    13    obl  13:obl:in
# 221  20         .         .  PUNCT     .            _     2  punct    2:punct
# 222          None      None   None  None         None  None   None       None
# 223          None      None   None  None         None  None   None       None
#
#                 9   ...    12        13    14    15    16    17    18    19  \
# 0    SpaceAfter=No  ...  None      None  None  None  None  None  None  None
# 1    SpaceAfter=No  ...  None      None  None  None  None  None  None  None
# 2                _  ...  None      None  None  None  None  None  None  None
# 3                _  ...  None      None  None  None  None  None  None  None
# 4                _  ...  None      None  None  None  None  None  None  None
# ..             ...  ...   ...       ...   ...   ...   ...   ...   ...   ...
# 219              _  ...     _         _     _  None  None  None  None  None
# 220  SpaceAfter=No  ...     _  ARGM-LOC     _  None  None  None  None  None
# 221              _  ...     _         _     _  None  None  None  None  None
# 222           None  ...  None      None  None  None  None  None  None  None
# 223           None  ...  None      None  None  None  None  None  None  None
#
#        20    21
# 0    None  None
# 1    None  None
# 2    None  None
# 3    None  None
# 4    None  None
# ..    ...   ...
# 219  None  None
# 220  None  None
# 221  None  None
# 222  None  None
# 223  None  None
#
# [224 rows x 22 columns]

# %%
train_data[not train_data['21'].isna()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 train_data[not train_data['21'].isna()]
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py:395, in RangeIndex.get_loc(self, key, method, tolerance)
#     393             raise KeyError(key) from err
#     394     self._check_indexing_error(key)
# --> 395     raise KeyError(key)
#     396 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: '21'

# %%
train_parsed = parse(train_data)

# %%
train_parsed[0][6]
# Out:
# {'id': 7,
#  'form': 'killed',
#  'lemma': 'kill',
#  'upos': 'VERB',
#  'xpos': 'VBD',
#  'feats': {'Mood': 'Ind', 'Tense': 'Past', 'VerbForm': 'Fin'},
#  'head': 1,
#  'deprel': 'parataxis',
#  'deps': [('parataxis', 1)],
#  'misc': None}
